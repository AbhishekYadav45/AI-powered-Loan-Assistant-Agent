# %%
# import sys
# import importlib

# sys.path.append(r"C:\Users\User\AI\loan_assistant")
# import rag.query_rag
# importlib.reload(rag.query_rag)

# from rag.query_rag import rag_answer

# %%
# print(rag_answer("What documents are required for home loan?"))
# Out:
# - Valid photo ID (e.g., driver's license, passport)
# - Proof of income (e.g., pay stubs, tax returns)
# - Employment verification
# - Credit report
# - Bank statements
# - Property details (if available)
# - Additional financial information (e.g., assets and liabilities)

# %%
# pip install openai chromadb streamlit
# Out:
# ...
#
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#     --------------------------------------- 0.5/21.7 MB 3.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.1/21.7 MB 10.9 MB/s eta 0:00:02
#    -------- ------------------------------- 4.5/21.7 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.0/21.7 MB 8.2 MB/s eta 0:00:02
#    ------------- -------------------------- 7.3/21.7 MB 7.6 MB/s eta 0:00:02
#    -------------- ------------------------- 7.6/21.7 MB 7.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 9.4/21.7 MB 6.9 MB/s eta 0:00:02
# ...

# %%
# pip install sentence-transformers chromadb openai streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.0 MB 11.3 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.0 MB 11.6 MB/s eta 0:00:01
#    ------------------ --------------------- 5.5/12.0 MB 8.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.0 MB 8.2 MB/s eta 0:00:01
#    ------------------------- -------------- 7.6/12.0 MB 7.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.0 MB 7.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.4/12.0 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.2/12.0 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.7/12.0 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.5/12.0 MB 4.9 MB/s eta 0:00:01
# ...

# %% [markdown]
# # One time (or after doc update)

# %%
cd loan_assistant
python rag/build_index.py
